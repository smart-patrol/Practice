# %%
import pandas as pd

df = pd.read_csv("C:\\Users\\Home\\Downloads\\titanic_train.csv")

df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
# converting variable type to another

real_num = 1
string_outcome = str(real_num)

integer_outcome = int(string_outcome)

float_outcome = float(integer_outcome)

# %%
type(string_outcome)
# Out:
# str

# %%
type(integer_outcome)
# Out:
# int

# %%
type(float_outcome)
# Out:
# float

# %%
# converting a character to a date
from datetime import datetime

char_date = 'Apr 1 2015 1:20PM'  # as char
date_obj = datetime.strptime(char_date, '%b %d %Y %I:%M%p')

print date_obj
# Out:
# 2015-04-01 13:20:00

# %%
# transposing a data set
list(df.columns.values)
# Out:
# ['PassengerId',
#  'Survived',
#  'Pclass',
#  'Name',
#  'Sex',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Ticket',
#  'Fare',
#  'Cabin',
#  'Embarked']

# %%
trans = df.pivot(index = 'PassengerId', columns = 'Survived', values = 'Age')

trans.head(3)
# Out:
# Survived      0   1
# PassengerId
# 1            22 NaN
# 2           NaN  38
# 3           NaN  26

# %%
# sorting a data frame
srted = df.sort(['Age', 'Survived'], ascending=[True, False])

srted.head(5)
# Out:
#      PassengerId  Survived  Pclass                             Name     Sex  \
# 803          804         1       3  Thomas, Master. Assad Alexander    male
# 755          756         1       2        Hamalainen, Master. Viljo    male
# 469          470         1       3    Baclini, Miss. Helene Barbara  female
# 644          645         1       3           Baclini, Miss. Eugenie  female
# 78            79         1       2    Caldwell, Master. Alden Gates    male
#
#       Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# 803  0.42      0      1    2625   8.5167   NaN        C
# 755  0.67      1      1  250649  14.5000   NaN        S
# 469  0.75      2      1    2666  19.2583   NaN        C
# 644  0.75      2      1    2666  19.2583   NaN        C
# 78   0.83      0      2  248738  29.0000   NaN        S

# %%
import matplotlib.pyplot as plt
import pandas as pd

fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.hist(df['Fare'])
plt.title('Age distribution')
plt.xlabel('Age')
plt.ylabel('#Employees')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\Home\Anaconda\lib\site-packages\matplotlib\backends\backend_qt5.pyc in closeEvent(self, event)
#     435     closing = QtCore.Signal()
#     436
# --> 437     def closeEvent(self, event):
#     438         self.closing.emit()
#     439         QtWidgets.QMainWindow.closeEvent(self, event)
#
# TypeError: 'int' object is not callable

# %%
# frequency tables with pands
test = df.groupby(['Sex', 'Survived']).Age.mean()

test
# Out:
# Sex     Survived
# female  0           25.046875
#         1           28.847716
# male    0           31.618056
#         1           27.276022
# Name: Age, dtype: float64

# %%
df.groupby(['Sex', 'Survived']).describe()
# Out:
#                               Age        Fare       Parch  PassengerId  \
# Sex    Survived
# female 0        count   64.000000   81.000000   81.000000    81.000000
#                 mean    25.046875   23.024385    1.037037   434.851852
#                 std     13.618591   24.821287    1.391442   263.522063
#                 min      2.000000    6.750000    0.000000    15.000000
#                 25%     16.750000    8.850000    0.000000   206.000000
#                 50%     24.500000   15.245800    0.000000   420.000000
#                 75%     33.250000   27.900000    2.000000   643.000000
#                 max     57.000000  151.550000    6.000000   889.000000
#        1        count  197.000000  233.000000  233.000000   233.000000
#                 mean    28.847716   51.938573    0.515021   429.699571
#                 std     14.175073   64.102256    0.820527   255.048296
#                 min      0.750000    7.225000    0.000000     2.000000
# ...

# %%
import seaborn as sns
sns.boxplot(df['Age'])
sns.despine()

# %%
# sampling data in python
import numpy as np
import pandas as pd
from random import sample

# create a random index of 5
rindex =  np.array(sample(xrange(len(df)), 5))

# get ranomd rows from df
dfr = df.ix[rindex]
print dfr
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 238          239         0       2            Pengelly, Mr. Frederick William
# 336          337         0       1                  Pears, Mr. Thomas Clinton
# 478          479         0       3                  Karlsson, Mr. Nils August
# 845          846         0       3                        Abbing, Mr. Anthony
# 347          348         1       3  Davison, Mrs. Thomas Henry (Mary E Finck)
#
#         Sex  Age  SibSp  Parch     Ticket     Fare Cabin Embarked
# 238    male   19      0      0      28665  10.5000   NaN        S
# 336    male   29      1      0     113776  66.6000    C2        S
# 478    male   22      0      0     350060   7.5208   NaN        S
# 845    male   42      0      0  C.A. 5547   7.5500   NaN        S
# 347  female  NaN      1      0     386525  16.1000   NaN        S

# %%
# removing duplicate values

rem_dup = df.drop_duplicates(['Sex', 'Cabin'])

rem_dup.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
# missing values in Pythion

df.Cabin.isnull().sum()
# Out:
# 687

# %%
df.Age.isnull().sum()
# Out:
# 177

# %%
# replace missing values with mean
import numpy as np

meanAge = np.mean(df.Age)
df.Age = df.Age.fillna(meanAge)

df.Age.isnull().sum()
# Out:
# 0

# %%
# merging and joining data sets

df_new = pd.merge(df, dfr, how = 'inner', left_index = True, right_index = True)
len(df_new)
# Out:
# 5
